# %%
import pandas as pd

# %%
df = pd.read_csv("./dados.csv")
df
# Out:
#                                                   href  \
# 0                             /the-weeknd/die-for-you/
# 1                                /the-weeknd/reminder/
# 2                         /the-weeknd/save-your-tears/
# 3                               /the-weeknd/the-hills/
# 4    /the-weeknd/one-of-the-girs-feat-jennie-e-lily...
# ..                                                 ...
# 279              /the-weeknd/danny-boy-styles-october/
# 280      /the-weeknd/off-the-table-feat-ariana-grande/
# 281                              /the-weeknd/pass-dat/
# 282                             /the-weeknd/the-delay/
# 283                /the-weeknd/when-i-pulling-up-demo/
#
#                                                  letra  \
# 0    I'm findin' ways to articulate the feeling I'm...
# 1    Record man play my song on the radio You too b...
# 2    Ooh Na na, yeah I saw you dancing in a crowded...
# 3    Yeah Yeah Yeah Your man on the road, he doin' ...
# 4    Lock me up and throw away the key He knows how...
# ..                                                 ...
# 279  I know 'bout your pain, no Was did after me Sh...
# 280  Will I ever love the same way again? (way agai...
# 281  [Starrah] Blunt after blunt after blunt after ...
# 282  Oh, hey, oh yeah, oh Let me know Can you let m...
# 283  I don't really know, when I know you're saying...
#
#                                                  nome
# 0                                         Die For You
# 1                                            Reminder
# 2                                     Save Your Tears
# 3                                           The Hills
# 4    One Of The Girls (feat. JENNIE & Lily-Rose Depp)
# ..                                                ...
# 279                          Danny Boy Styles October
# 280               off the table (feat. Ariana Grande)
# 281        Pass Dat (remix) (feat. Jeremih & Starrah)
# 282                                         The Delay
# 283                          When I (Pulling Up Demo)
#
# [284 rows x 3 columns]

# %%
df['contagem_XO'] = df['letra'].str.count('XO')
df_sorted = df.sort_values(by='contagem_XO', ascending=False)
result_df = df_sorted[['nome', 'contagem_XO']]
result_df
# Out:
#                                            nome  contagem_XO
# 142                               Xo / The Host           10
# 187                                  Initiation           10
# 149                            King Of The Fall            5
# 186                                    The Fall            4
# 184                      Live For (feat. Drake)            1
# ..                                          ...          ...
# 101                  You Right (feat. Doja Cat)            0
# 102  False Idols (feat. Lil Baby & Suzanna Son)            0
# 103                     I Feel It Coming (Live)            0
# 104               Dark Times (feat. Ed Sheeran)            0
# 283                    When I (Pulling Up Demo)            0
#
# [284 rows x 2 columns]
