# %%
import pandas as pd

# %%
df = pd.read_csv("./dadosToSpotify.csv")
df
# Out:
#                                                   href  \
# 0                             /the-weeknd/die-for-you/
# 1    /the-weeknd/one-of-the-girs-feat-jennie-e-lily...
# 2                                /the-weeknd/reminder/
# 3                         /the-weeknd/save-your-tears/
# 4                               /the-weeknd/the-hills/
# ..                                                 ...
# 197  /the-weeknd/sacrifice-remix-feat-swedish-house...
# 198  /the-weeknd/take-my-breath-remix-feat-agents-o...
# 199                     /the-weeknd/glass-table-girls/
# 200                        /the-weeknd/the-birds-demo/
# 201                /the-weeknd/gone-tell-your-friends/
#
#                                                  letra               nome  \
# 0    I'm findin' ways to articulate the feeling I'm...        Die For You
# 1    Lock me up and throw away the key He knows how...  One Of The Girls
# 2    Record man play my song on the radio You too b...           Reminder
# 3    Ooh Na na, yeah I saw you dancing in a crowded...    Save Your Tears
# 4    Yeah Yeah Yeah Your man on the road, he doin' ...          The Hills
# ..                                                 ...                ...
# 197  I was born in a city Where the winter nights d...         Sacrifice
# 198  I saw the fire in your eyes You tell me things...    Take My Breath
# 199  La la la la la la la la (?) with the homies wh...  Glass Table Girls
# 200  So you see, that You won't ever mean to me You...         The Birds
# 201  Gone I'm gone Gone I'm gone, I'm gone I'm gone...              Gone
#
#                                                  album                 trackID
# 0                                              Starboy  2LBqCSwhJGcFQeTHMVGwy3
# 1    The Idol Episode 4 (Music from the HBO Origina...  7CyPwkp0oE8Ro9Dd5CUDjW
# 2                                              Starboy  37F0uwRSrdzkBiuj0D5UHI
# 3                                          After Hours  5QO79kh1waicV47BqGRL3g
# 4                            Beauty Behind The Madness  7fBv7CLKzipRk6EC6TWHOB
# ..                                                 ...                     ...
# 197                                Silvester Party Mix  5oN2akg172uk3P8odbjtQ6
# 198                                            Dawn FM  2vgUijXOTRMnWXDtvgMp2b
# 199                       House Of Balloons (Original)  2r7BPog74oaTG5shNYiUnV
# 200                                Thursday (Original)  2yYDijitHN6psA2tH0ndXs
# 201                                Thursday (Original)  7xgYvziLsxNd0UznaEw8Oi
#
# [202 rows x 5 columns]

# %%
df['contagem_XO'] = df['letra'].str.count('XO')
df_sorted = df.sort_values(by='contagem_XO', ascending=False)
result_df = df_sorted[['nome', 'contagem_XO']]
result_df
# Out:
#                   nome  contagem_XO
# 123      Xo / The Host           10
# 159         Initiation           10
# 127   King Of The Fall            5
# 182           The Fall            4
# 152            Or Nah             1
# ..                 ...          ...
# 69         False Alarm            0
# 70    Nothing Compares            0
# 71      Six Feet Under            0
# 72   Tears in The Rain            0
# 201              Gone             0
#
# [202 rows x 2 columns]

# %%
df.drop_duplicates(subset='nome', keep='first')
df
# Out:
#                                                   href  \
# 0                             /the-weeknd/die-for-you/
# 1    /the-weeknd/one-of-the-girs-feat-jennie-e-lily...
# 2                                /the-weeknd/reminder/
# 3                         /the-weeknd/save-your-tears/
# 4                               /the-weeknd/the-hills/
# ..                                                 ...
# 197  /the-weeknd/sacrifice-remix-feat-swedish-house...
# 198  /the-weeknd/take-my-breath-remix-feat-agents-o...
# 199                     /the-weeknd/glass-table-girls/
# 200                        /the-weeknd/the-birds-demo/
# 201                /the-weeknd/gone-tell-your-friends/
#
#                                                  letra               nome  \
# 0    I'm findin' ways to articulate the feeling I'm...        Die For You
# 1    Lock me up and throw away the key He knows how...  One Of The Girls
# 2    Record man play my song on the radio You too b...           Reminder
# 3    Ooh Na na, yeah I saw you dancing in a crowded...    Save Your Tears
# 4    Yeah Yeah Yeah Your man on the road, he doin' ...          The Hills
# ..                                                 ...                ...
# 197  I was born in a city Where the winter nights d...         Sacrifice
# 198  I saw the fire in your eyes You tell me things...    Take My Breath
# 199  La la la la la la la la (?) with the homies wh...  Glass Table Girls
# 200  So you see, that You won't ever mean to me You...         The Birds
# 201  Gone I'm gone Gone I'm gone, I'm gone I'm gone...              Gone
#
#                                                  album                 trackID
# 0                                              Starboy  2LBqCSwhJGcFQeTHMVGwy3
# 1    The Idol Episode 4 (Music from the HBO Origina...  7CyPwkp0oE8Ro9Dd5CUDjW
# 2                                              Starboy  37F0uwRSrdzkBiuj0D5UHI
# 3                                          After Hours  5QO79kh1waicV47BqGRL3g
# 4                            Beauty Behind The Madness  7fBv7CLKzipRk6EC6TWHOB
# ..                                                 ...                     ...
# 197                                Silvester Party Mix  5oN2akg172uk3P8odbjtQ6
# 198                                            Dawn FM  2vgUijXOTRMnWXDtvgMp2b
# 199                       House Of Balloons (Original)  2r7BPog74oaTG5shNYiUnV
# 200                                Thursday (Original)  2yYDijitHN6psA2tH0ndXs
# 201                                Thursday (Original)  7xgYvziLsxNd0UznaEw8Oi
#
# [202 rows x 5 columns]

# %%
name_counts = df['nome'].value_counts()
repetitive_names = name_counts[name_counts > 1]

print(repetitive_names)
# Out:
# nome
# Blinding Lights       3
# Take My Breath        3
# Heartless             3
# The Hills             3
# Starboy               3
# Die For You           3
# Best Friends          2
# Low Life              2
# Sacrifice             2
# In Your Eyes          2
# Crew Love             2
# Save Your Tears       2
# Or Nah                2
# I Feel It Coming      2
# The Birds             2
# Hurricane             2
# I Was Never There     2
# Often                 2
# Name: count, dtype: int64

# %%
duplicate_mask = df.duplicated(subset='nome', keep=False)

# Invert the mask to keep only non-duplicate rows
df[~duplicate_mask]
# Out:
#                                                   href  \
# 0                             /the-weeknd/die-for-you/
# 1    /the-weeknd/one-of-the-girs-feat-jennie-e-lily...
# 2                                /the-weeknd/reminder/
# 3                         /the-weeknd/save-your-tears/
# 4                               /the-weeknd/the-hills/
# ..                                                 ...
# 193                    /the-weeknd/secrets-feat-jr-hi/
# 194           /the-weeknd/starry-eyes-mike-dean-remix/
# 196                                 /the-weeknd/party/
# 199                     /the-weeknd/glass-table-girls/
# 201                /the-weeknd/gone-tell-your-friends/
#
#                                                  letra               nome  \
# 0    I'm findin' ways to articulate the feeling I'm...        Die For You
# 1    Lock me up and throw away the key He knows how...  One Of The Girls
# 2    Record man play my song on the radio You too b...           Reminder
# 3    Ooh Na na, yeah I saw you dancing in a crowded...    Save Your Tears
# 4    Yeah Yeah Yeah Your man on the road, he doin' ...          The Hills
# ..                                                 ...                ...
# 193  [The Weeknd] I've spent most of my time With y...           Secrets
# 194  I only met you in my dreams before When I was ...       Starry Eyes
# 196  See the rides pull in And the place pack up On...              Party
# 199  La la la la la la la la (?) with the homies wh...  Glass Table Girls
# 201  Gone I'm gone Gone I'm gone, I'm gone I'm gone...              Gone
#
#                                                  album                 trackID
# 0                                              Starboy  2LBqCSwhJGcFQeTHMVGwy3
# 1    The Idol Episode 4 (Music from the HBO Origina...  7CyPwkp0oE8Ro9Dd5CUDjW
# 2                                              Starboy  37F0uwRSrdzkBiuj0D5UHI
# 3                                          After Hours  5QO79kh1waicV47BqGRL3g
# 4                            Beauty Behind The Madness  7fBv7CLKzipRk6EC6TWHOB
# ..                                                 ...                     ...
# 193                                            Starboy  00NAQYOP4AmWR549nnYJZu
# 194                                            Dawn FM  6zzdyvVWjGrQBraSvuqJPY
# 196                                            Starboy  4F7A0DXBrmUAkp32uenhZt
# 199                       House Of Balloons (Original)  2r7BPog74oaTG5shNYiUnV
# 201                                Thursday (Original)  7xgYvziLsxNd0UznaEw8Oi
#
# [160 rows x 5 columns]
